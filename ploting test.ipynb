# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
x = np.random.randn(10)*10
y = np.random.randn(10)*10

# %%
x
# Out:
# array([-12.92004   ,   6.84055437,   9.64951056,  -2.11490773,
#         -5.48362557,  -1.41876407,   8.00542926,   9.57304557,
#          4.79510105,  -6.7791408 ])

# %%
y
# Out:
# array([ -8.7206552 ,  -4.12039121,  -3.43062697,  -4.24332388,
#          2.54214649,   4.06305363,  -0.57593791,  19.28527737,
#        -23.20776933,  11.56208456])

# %%
sns.scatterplot(x, y)
plt.plot(range(-20, 20), range(-20, 20), color='green')
# for xx, yy in zip(x, y):
#     plt

# %%
plt.plot(range(-20, 20), range(-20, 20), color='green')
for i in range(len(x)):
    xx = int(x[i])
    yy = int(y[i])
    plt.plot([xx, xx], [yy, xx])

# %%
sns.scatterplot(x, y)
plt.plot(range(-20, 20), range(-20, 20), color='green')
for i in range(len(x)):
    xx = int(x[i])
    yy = int(y[i])
    plt.plot([xx, xx], [yy, xx])
